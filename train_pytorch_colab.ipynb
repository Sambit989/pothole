# %% [markdown]
# # YOLOv4 Training (Colab)\nThis notebook contains instructions and code snippets to train a YOLOv4 model using a PyTorch implementation. Replace placeholders with actual implementations.

# %%
# Clone dataset\n!git clone https://github.com/jaygala24/pothole-detection.git dataset/jaygala

# %%
# Install libs\n!pip install -r requirements.txt
